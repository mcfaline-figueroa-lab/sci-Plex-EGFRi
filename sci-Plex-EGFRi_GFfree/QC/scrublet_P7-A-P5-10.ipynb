# %%
# !pip install scrublet
# Out:
# Requirement already satisfied: scrublet in /Users/rossgiglio/opt/anaconda3/lib/python3.9/site-packages (0.2.3)
# Requirement already satisfied: scipy in /Users/rossgiglio/opt/anaconda3/lib/python3.9/site-packages (from scrublet) (1.13.1)
# Requirement already satisfied: scikit-image in /Users/rossgiglio/opt/anaconda3/lib/python3.9/site-packages (from scrublet) (0.19.2)
# Requirement already satisfied: numpy in /Users/rossgiglio/opt/anaconda3/lib/python3.9/site-packages (from scrublet) (1.26.4)
# Requirement already satisfied: cython in /Users/rossgiglio/opt/anaconda3/lib/python3.9/site-packages (from scrublet) (0.29.28)
# Requirement already satisfied: umap-learn in /Users/rossgiglio/opt/anaconda3/lib/python3.9/site-packages (from scrublet) (0.5.6)
# Requirement already satisfied: pandas in /Users/rossgiglio/opt/anaconda3/lib/python3.9/site-packages (from scrublet) (2.2.3)
# Requirement already satisfied: scikit-learn in /Users/rossgiglio/opt/anaconda3/lib/python3.9/site-packages (from scrublet) (1.5.0)
# Requirement already satisfied: annoy in /Users/rossgiglio/opt/anaconda3/lib/python3.9/site-packages (from scrublet) (1.17.1)
# Requirement already satisfied: matplotlib in /Users/rossgiglio/opt/anaconda3/lib/python3.9/site-packages (from scrublet) (3.9.0)
# Requirement already satisfied: numba in /Users/rossgiglio/opt/anaconda3/lib/python3.9/site-packages (from scrublet) (0.60.0)
# Requirement already satisfied: pillow>=8 in /Users/rossgiglio/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->scrublet) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/rossgiglio/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->scrublet) (3.1.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/rossgiglio/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->scrublet) (4.53.0)
# Requirement already satisfied: cycler>=0.10 in /Users/rossgiglio/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->scrublet) (0.12.1)
# Requirement already satisfied: packaging>=20.0 in /Users/rossgiglio/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->scrublet) (24.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/rossgiglio/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->scrublet) (6.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/rossgiglio/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->scrublet) (2.9.0.post0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/rossgiglio/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->scrublet) (1.4.5)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/rossgiglio/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->scrublet) (1.2.1)
# Requirement already satisfied: zipp>=3.1.0 in /Users/rossgiglio/opt/anaconda3/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->scrublet) (3.19.2)
# Requirement already satisfied: six>=1.5 in /Users/rossgiglio/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->scrublet) (1.16.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /Users/rossgiglio/opt/anaconda3/lib/python3.9/site-packages (from numba->scrublet) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/rossgiglio/opt/anaconda3/lib/python3.9/site-packages (from pandas->scrublet) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/rossgiglio/opt/anaconda3/lib/python3.9/site-packages (from pandas->scrublet) (2024.1)
# Requirement already satisfied: networkx>=2.2 in /Users/rossgiglio/opt/anaconda3/lib/python3.9/site-packages (from scikit-image->scrublet) (3.2.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /Users/rossgiglio/opt/anaconda3/lib/python3.9/site-packages (from scikit-image->scrublet) (2021.7.2)
# Requirement already satisfied: PyWavelets>=1.1.1 in /Users/rossgiglio/opt/anaconda3/lib/python3.9/site-packages (from scikit-image->scrublet) (1.3.0)
# Requirement already satisfied: imageio>=2.4.1 in /Users/rossgiglio/opt/anaconda3/lib/python3.9/site-packages (from scikit-image->scrublet) (2.9.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/rossgiglio/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn->scrublet) (3.5.0)
# Requirement already satisfied: joblib>=1.2.0 in /Users/rossgiglio/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn->scrublet) (1.4.2)
# Requirement already satisfied: pynndescent>=0.5 in /Users/rossgiglio/opt/anaconda3/lib/python3.9/site-packages (from umap-learn->scrublet) (0.5.13)
# Requirement already satisfied: tqdm in /Users/rossgiglio/opt/anaconda3/lib/python3.9/site-packages (from umap-learn->scrublet) (4.66.4)

# %%
import scrublet as scr
import scipy.io as sp
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
#read in the expression matrix and make sure that the dimensions are in cells x genes
mat = sp.mmread("UMI_count_filt.mtx")
mat
# Out:
# <43904x58347 sparse matrix of type '<class 'numpy.int64'>'
# 	with 51678199 stored elements in COOrdinate format>

# %%
#input the collision rate from the birthday problem into the expected doublet rate
scrub = scr.Scrublet(mat, expected_doublet_rate=0.04)

# %%
doublet_scores, predicted_doublets = scrub.scrub_doublets(min_counts=2, 
                                                          min_cells=3, 
                                                          min_gene_variability_pctl=85, 
                                                          n_prin_comps=30)
# Out:
# Preprocessing...
# Simulating doublets...
# Embedding transcriptomes using PCA...
# Calculating doublet scores...
# Automatically set threshold at doublet score = 0.74
# Detected doublet rate = 0.0%
# Estimated detectable doublet fraction = 0.1%
# Overall doublet rate:
# 	Expected   = 4.0%
# 	Estimated  = 5.0%
# Elapsed time: 199.4 seconds

# %%
scrub.call_doublets(threshold=0.4)
# Out:
# Detected doublet rate = 0.2%
# Estimated detectable doublet fraction = 7.5%
# Overall doublet rate:
# 	Expected   = 4.0%
# 	Estimated  = 3.1%
# array([False, False, False, ..., False, False, False])

# %%
scrub.plot_histogram()[0].savefig("scrublet_histogram.png");

# %%
print('Running UMAP...')
scrub.set_embedding('UMAP', scr.get_umap(scrub.manifold_obs_, 10, min_dist=0.1))

print('Done.')
# Out:
# Running UMAP...
# /Users/rossgiglio/opt/anaconda3/lib/python3.9/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# /Users/rossgiglio/opt/anaconda3/lib/python3.9/site-packages/numba/np/ufunc/parallel.py:371: NumbaWarning: The TBB threading layer requires TBB version 2021 update 6 or later i.e., TBB_INTERFACE_VERSION >= 12060. Found TBB_INTERFACE_VERSION = 12050. The TBB threading layer is disabled.
#   warnings.warn(problem)
# OMP: Info #271: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# Done.

# %%
scrub.plot_embedding('UMAP', order_points=True)[0].savefig("UMAP_doublets.png");

# %%
np.savetxt(fname = "doublet_scores.txt", X = doublet_scores)
np.savetxt(fname = "predicted_doublets.txt", X = predicted_doublets)
